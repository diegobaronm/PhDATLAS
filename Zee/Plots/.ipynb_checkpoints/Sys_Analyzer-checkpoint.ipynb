# %%
import os
trees=["NOMINAL"]
with open("../MC/sys_trees.txt","r") as file:
    line=file.readline()
    while line:
        trees.append(line.rstrip('\n'))
        line=file.readline()

samples=["Signal_Sherpa","Signal_PoPy","VV"]

for i in samples:
    for t in trees:
        os.system("cp ../MC/out/"+i+t+".root .")

# %%
import ROOT as r
dict={}


# FILLING DICTIONARY WITH SYS-RELATED TREES 

### the dictionary will have the following structure "systematic_name":[yield]

for sam in samples:
    for sys in trees[1:]:
        file=r.TFile.Open(sam+sys+".root")
        sys_yield=file.Get("ratio_lpt_tpt_cuts_ptl")
        dict[sam+sys]=[sys_yield.Integral(0,50)]
        file.Close()

#NOW ADDING THE WEIGHT-BASED SYSTEMATICS        
histograms=[]
for sys in trees[:1]:
    file=r.TFile.Open("Signal_Sherpa"+sys+".root")
    histos=file.GetListOfKeys()
    for i in histos:
        name=i.GetName()
        if ("cuts" in name) and ("ptl" in name) and ("yield" in name):
            histograms.append(i.GetName()[len("yield_sys_cuts_ptl_"):])


for sam in samples:
    for sys in trees[:1]:
        file=r.TFile.Open(sam+sys+".root")
        for h in histograms:
            sys_yield=file.Get("yield_sys_cuts_ptl_"+h)
            dict[sam+sys+h]=[sys_yield.Integral(0,50)]
        file.Close()

# %%
#The structure of the dictionary is... "name_of_sys":[Sherpa,PoPy,VV]
final_dict={}
for i in histograms:
    final_dict[i]=[0,0,0]
    for j in dict:
        if (i in j) and ("Sherpa" in j):
            final_dict[i][0]=dict[j]
        if (i in j) and ("PoPy" in j):
            final_dict[i][1]=dict[j]
        if (i in j) and ("VV" in j):
            final_dict[i][2]=dict[j]
            
#TAKING DOWN AND UP SYSTEMATICS TO THE BOTTOM AND THE TOP OF THE DICTIONARY RESPECTIVELY
up={}
down={}

a_keys=[i for i in final_dict]

for i in a_keys:
    if "1down" in i:
        down.update({i:final_dict[i]})
        final_dict.pop(i)

final_dict.update(down)

# %%
# EXPORTING THE RESULTS TO A CSV FILE
import pandas as pd
df=pd.DataFrame.from_dict(final_dict, orient='index',
                       columns=["Sherpa","PoPy","VV"])


df.to_csv('Weight-Based-Uncertainties.csv')

# %%
df
# Out:
#                                                                   Sherpa  \
# elec_0_EL_EFF_ID_TOTAL_1NPCOR_PLUS_UNCOR_1up_El...  [325744.40911865234]
# elec_0_EL_EFF_Iso_TOTAL_1NPCOR_PLUS_UNCOR_1up_E...  [322431.79412841797]
# elec_0_EL_EFF_Iso_TOTAL_1NPCOR_PLUS_UNCOR_1up_E...   [322670.6336669922]
# elec_0_EL_EFF_Reco_TOTAL_1NPCOR_PLUS_UNCOR_1up_...   [322782.4398803711]
# elec_0_EL_EFF_Trigger_TOTAL_1NPCOR_PLUS_UNCOR_1...   [322815.7747192383]
# ...                                                                  ...
# jet_FT_EFF_extrapolation_from_charm_1down_globa...   [322237.2973022461]
# jet_JET_JvtEfficiency_1down_central_jets_global...                 [nan]
# jet_JET_JvtEfficiency_1down_central_jets_global...  [323115.21447753906]
# jet_JET_fJvtEfficiency_1down_forward_jets_globa...  [321059.59283447266]
# jet_JET_fJvtEfficiency_1down_forward_jets_globa...   [323463.8871459961]
#
#                                                                     PoPy  \
# elec_0_EL_EFF_ID_TOTAL_1NPCOR_PLUS_UNCOR_1up_El...   [340118.3815307617]
# elec_0_EL_EFF_Iso_TOTAL_1NPCOR_PLUS_UNCOR_1up_E...   [336745.9182128906]
# elec_0_EL_EFF_Iso_TOTAL_1NPCOR_PLUS_UNCOR_1up_E...  [336996.59381103516]
# elec_0_EL_EFF_Reco_TOTAL_1NPCOR_PLUS_UNCOR_1up_...  [337120.57037353516]
# elec_0_EL_EFF_Trigger_TOTAL_1NPCOR_PLUS_UNCOR_1...   [337156.3635864258]
# ...                                                                  ...
# jet_FT_EFF_extrapolation_from_charm_1down_globa...   [336553.1919555664]
# jet_JET_JvtEfficiency_1down_central_jets_global...  [335504.85357666016]
# jet_JET_JvtEfficiency_1down_central_jets_global...   [337251.6096801758]
# jet_JET_fJvtEfficiency_1down_forward_jets_globa...  [335649.83880615234]
# jet_JET_fJvtEfficiency_1down_forward_jets_globa...   [337466.7658691406]
#
#                                                                       VV
# elec_0_EL_EFF_ID_TOTAL_1NPCOR_PLUS_UNCOR_1up_El...   [6916.122032165527]
# elec_0_EL_EFF_Iso_TOTAL_1NPCOR_PLUS_UNCOR_1up_E...   [6837.566173553467]
# elec_0_EL_EFF_Iso_TOTAL_1NPCOR_PLUS_UNCOR_1up_E...   [6842.784158706665]
# elec_0_EL_EFF_Reco_TOTAL_1NPCOR_PLUS_UNCOR_1up_...  [6844.0639934539795]
# elec_0_EL_EFF_Trigger_TOTAL_1NPCOR_PLUS_UNCOR_1...   [6844.148529052734]
# ...                                                                  ...
# jet_FT_EFF_extrapolation_from_charm_1down_globa...   [6839.025682449341]
# jet_JET_JvtEfficiency_1down_central_jets_global...                 [nan]
# jet_JET_JvtEfficiency_1down_central_jets_global...   [6857.765184402466]
# jet_JET_fJvtEfficiency_1down_forward_jets_globa...   [6803.318344116211]
# jet_JET_fJvtEfficiency_1down_forward_jets_globa...   [6868.484546661377]
#
# [80 rows x 3 columns]
