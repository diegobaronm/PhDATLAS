# %%
import os
trees=["NOMINAL1","NOMINAL2"]
with open("../MC/sys_trees1.txt","r") as file:
    line=file.readline()
    while line:
        trees.append(line.rstrip('\n'))
        line=file.readline()
        
with open("../MC/sys_trees2.txt","r") as file:
    line=file.readline()
    while line:
        trees.append(line.rstrip('\n'))
        line=file.readline()
        
samples=["Signal_Sherpa","Signal_PoPy","Zmumu","VV"]

for i in samples:
    for t in trees:
        os.system("cp ../MC/out/"+i+t+".root .")

# %%
import ROOT as r
dict={}

# FILLING DICTIONARY WITH SYS-RELATED TREES
for sam in samples:
    for sys in trees[2:]:
        file=r.TFile.Open(sam+sys+".root")
        prong1=file.Get("tau_matched_1p_topo_dphi_btag_iso_rnn_ptmu_omega_mreco_tpt")
        prong3=file.Get("tau_matched_3p_topo_dphi_btag_iso_rnn_ptmu_omega_mreco_tpt")
        dict[sam+sys]=[1,2,3,4]
        file.Close()

#NOW ADDING THE WEIGHT-BASED SYSTEMATICS        
histograms=[]
for sys in trees[:2]:
    file=r.TFile.Open("Signal_Sherpa"+sys+".root")
    histos=file.GetListOfKeys()
    for i in histos:
        name=i.GetName()
        if ("cuts" in name) and ("tpt" in name) and ("1p" in name):
            histograms.append(i.GetName()[len("tau_matched_1p_cuts_tpt_"):])

for sam in samples:
    for sys in trees[2:]:
        file=r.TFile.Open(sam+sys+".root")
        for h in histograms:
            prong1=file.Get("tau_matched_1p_cuts_tpt_"+h)
            prong3=file.Get("tau_matched_3p_cuts_tpt_"+h)
            dict[sam+sys+h]=[prong1.Integral(0,1),prong1.Integral(1,2),prong3.Integral(0,1),prong3.Integral(1,2)]
        file.Close()
# Out:
# <cppyy.gbl.TObject object at 0x(nil)>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-a51175cbf927> in <module>
#      28             print(prong1)
#      29             prong3=file.Get("tau_matched_3p_cuts_tpt_"+h)
# ---> 30             dict[sam+sys+h]=[prong1.Integral(0,1),prong1.Integral(1,2),prong3.Integral(0,1),prong3.Integral(1,2)]
#      31         file.Close()
#
# AttributeError: 'TObject' object has no attribute 'Integral'

# %%
dict
# Out:
# {'Signal_SherpaMET_SoftTrk_ResoPara': [1, 2, 3, 4],
#  'Signal_SherpaMET_SoftTrk_ResoPerp': [1, 2, 3, 4],
#  'Signal_SherpaMET_SoftTrk_Scale_1down': [1, 2, 3, 4],
#  'Signal_SherpaMET_SoftTrk_Scale_1up': [1, 2, 3, 4],
#  'Signal_SherpaMUON_ID_1down': [1, 2, 3, 4],
#  'Signal_SherpaMUON_ID_1up': [1, 2, 3, 4],
#  'Signal_SherpaMUON_MS_1down': [1, 2, 3, 4],
#  'Signal_SherpaMUON_MS_1up': [1, 2, 3, 4],
#  'Signal_SherpaMUON_SAGITTA_RESBIAS_1down': [1, 2, 3, 4],
#  'Signal_SherpaMUON_SAGITTA_RESBIAS_1up': [1, 2, 3, 4],
#  'Signal_SherpaMUON_SAGITTA_RHO_1down': [1, 2, 3, 4],
#  'Signal_SherpaMUON_SAGITTA_RHO_1up': [1, 2, 3, 4],
#  'Signal_SherpaMUON_SCALE_1down': [1, 2, 3, 4],
#  'Signal_SherpaMUON_SCALE_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_EtaIntercalibration_NonClosure_2018data_1down': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaJET_EtaIntercalibration_NonClosure_2018data_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_EtaIntercalibration_NonClosure_highE_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_EtaIntercalibration_NonClosure_highE_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_EtaIntercalibration_NonClosure_negEta_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_EtaIntercalibration_NonClosure_negEta_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_EtaIntercalibration_NonClosure_posEta_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_EtaIntercalibration_NonClosure_posEta_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_Flavor_Response_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_Flavor_Response_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_GroupedNP_1_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_GroupedNP_1_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_GroupedNP_2_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_GroupedNP_2_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_GroupedNP_3_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_GroupedNP_3_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_DataVsMC_MC16_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_DataVsMC_MC16_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_1_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_1_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_2_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_2_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_3_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_3_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_4_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_4_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_5_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_5_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_6_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_6_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_7restTerm_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_JER_EffectiveNP_7restTerm_1up': [1, 2, 3, 4],
#  'Signal_SherpaJET_TILECORR_Uncertainty_1down': [1, 2, 3, 4],
#  'Signal_SherpaJET_TILECORR_Uncertainty_1up': [1, 2, 3, 4],
#  'Signal_SherpaTAUS_TRUEHADTAU_SME_TES_DETECTOR_1down': [1, 2, 3, 4],
#  'Signal_SherpaTAUS_TRUEHADTAU_SME_TES_DETECTOR_1up': [1, 2, 3, 4],
#  'Signal_SherpaTAUS_TRUEHADTAU_SME_TES_INSITUEXP_1down': [1, 2, 3, 4],
#  'Signal_SherpaTAUS_TRUEHADTAU_SME_TES_INSITUEXP_1up': [1, 2, 3, 4],
#  'Signal_SherpaTAUS_TRUEHADTAU_SME_TES_INSITUFIT_1down': [1, 2, 3, 4],
#  'Signal_SherpaTAUS_TRUEHADTAU_SME_TES_INSITUFIT_1up': [1, 2, 3, 4],
#  'Signal_SherpaTAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE_1down': [1, 2, 3, 4],
#  'Signal_SherpaTAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE_1up': [1, 2, 3, 4],
#  'Signal_SherpaTAUS_TRUEHADTAU_SME_TES_PHYSICSLIST_1down': [1, 2, 3, 4],
#  'Signal_SherpaTAUS_TRUEHADTAU_SME_TES_PHYSICSLIST_1up': [1, 2, 3, 4],
#  'Signal_PoPyMET_SoftTrk_ResoPara': [1, 2, 3, 4],
#  'Signal_PoPyMET_SoftTrk_ResoPerp': [1, 2, 3, 4],
#  'Signal_PoPyMET_SoftTrk_Scale_1down': [1, 2, 3, 4],
#  'Signal_PoPyMET_SoftTrk_Scale_1up': [1, 2, 3, 4],
#  'Signal_PoPyMUON_ID_1down': [1, 2, 3, 4],
#  'Signal_PoPyMUON_ID_1up': [1, 2, 3, 4],
#  'Signal_PoPyMUON_MS_1down': [1, 2, 3, 4],
#  'Signal_PoPyMUON_MS_1up': [1, 2, 3, 4],
#  'Signal_PoPyMUON_SAGITTA_RESBIAS_1down': [1, 2, 3, 4],
#  'Signal_PoPyMUON_SAGITTA_RESBIAS_1up': [1, 2, 3, 4],
#  'Signal_PoPyMUON_SAGITTA_RHO_1down': [1, 2, 3, 4],
#  'Signal_PoPyMUON_SAGITTA_RHO_1up': [1, 2, 3, 4],
#  'Signal_PoPyMUON_SCALE_1down': [1, 2, 3, 4],
#  'Signal_PoPyMUON_SCALE_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_EtaIntercalibration_NonClosure_2018data_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_EtaIntercalibration_NonClosure_2018data_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_EtaIntercalibration_NonClosure_highE_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_EtaIntercalibration_NonClosure_highE_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_EtaIntercalibration_NonClosure_negEta_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_EtaIntercalibration_NonClosure_negEta_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_EtaIntercalibration_NonClosure_posEta_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_EtaIntercalibration_NonClosure_posEta_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_Flavor_Response_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_Flavor_Response_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_GroupedNP_1_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_GroupedNP_1_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_GroupedNP_2_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_GroupedNP_2_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_GroupedNP_3_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_GroupedNP_3_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_DataVsMC_MC16_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_DataVsMC_MC16_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_1_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_1_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_2_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_2_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_3_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_3_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_4_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_4_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_5_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_5_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_6_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_6_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_7restTerm_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_JER_EffectiveNP_7restTerm_1up': [1, 2, 3, 4],
#  'Signal_PoPyJET_TILECORR_Uncertainty_1down': [1, 2, 3, 4],
#  'Signal_PoPyJET_TILECORR_Uncertainty_1up': [1, 2, 3, 4],
#  'Signal_PoPyTAUS_TRUEHADTAU_SME_TES_DETECTOR_1down': [1, 2, 3, 4],
#  'Signal_PoPyTAUS_TRUEHADTAU_SME_TES_DETECTOR_1up': [1, 2, 3, 4],
#  'Signal_PoPyTAUS_TRUEHADTAU_SME_TES_INSITUEXP_1down': [1, 2, 3, 4],
#  'Signal_PoPyTAUS_TRUEHADTAU_SME_TES_INSITUEXP_1up': [1, 2, 3, 4],
#  'Signal_PoPyTAUS_TRUEHADTAU_SME_TES_INSITUFIT_1down': [1, 2, 3, 4],
#  'Signal_PoPyTAUS_TRUEHADTAU_SME_TES_INSITUFIT_1up': [1, 2, 3, 4],
#  'Signal_PoPyTAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE_1down': [1, 2, 3, 4],
#  'Signal_PoPyTAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE_1up': [1, 2, 3, 4],
#  'Signal_PoPyTAUS_TRUEHADTAU_SME_TES_PHYSICSLIST_1down': [1, 2, 3, 4],
#  'Signal_PoPyTAUS_TRUEHADTAU_SME_TES_PHYSICSLIST_1up': [1, 2, 3, 4],
#  'ZmumuMET_SoftTrk_ResoPara': [1, 2, 3, 4],
#  'ZmumuMET_SoftTrk_ResoPerp': [1, 2, 3, 4],
#  'ZmumuMET_SoftTrk_Scale_1down': [1, 2, 3, 4],
#  'ZmumuMET_SoftTrk_Scale_1up': [1, 2, 3, 4],
#  'ZmumuMUON_ID_1down': [1, 2, 3, 4],
#  'ZmumuMUON_ID_1up': [1, 2, 3, 4],
#  'ZmumuMUON_MS_1down': [1, 2, 3, 4],
#  'ZmumuMUON_MS_1up': [1, 2, 3, 4],
#  'ZmumuMUON_SAGITTA_RESBIAS_1down': [1, 2, 3, 4],
#  'ZmumuMUON_SAGITTA_RESBIAS_1up': [1, 2, 3, 4],
#  'ZmumuMUON_SAGITTA_RHO_1down': [1, 2, 3, 4],
#  'ZmumuMUON_SAGITTA_RHO_1up': [1, 2, 3, 4],
#  'ZmumuMUON_SCALE_1down': [1, 2, 3, 4],
#  'ZmumuMUON_SCALE_1up': [1, 2, 3, 4],
#  'ZmumuJET_EtaIntercalibration_NonClosure_2018data_1down': [1, 2, 3, 4],
#  'ZmumuJET_EtaIntercalibration_NonClosure_2018data_1up': [1, 2, 3, 4],
#  'ZmumuJET_EtaIntercalibration_NonClosure_highE_1down': [1, 2, 3, 4],
#  'ZmumuJET_EtaIntercalibration_NonClosure_highE_1up': [1, 2, 3, 4],
#  'ZmumuJET_EtaIntercalibration_NonClosure_negEta_1down': [1, 2, 3, 4],
#  'ZmumuJET_EtaIntercalibration_NonClosure_negEta_1up': [1, 2, 3, 4],
#  'ZmumuJET_EtaIntercalibration_NonClosure_posEta_1down': [1, 2, 3, 4],
#  'ZmumuJET_EtaIntercalibration_NonClosure_posEta_1up': [1, 2, 3, 4],
#  'ZmumuJET_Flavor_Response_1down': [1, 2, 3, 4],
#  'ZmumuJET_Flavor_Response_1up': [1, 2, 3, 4],
#  'ZmumuJET_GroupedNP_1_1down': [1, 2, 3, 4],
#  'ZmumuJET_GroupedNP_1_1up': [1, 2, 3, 4],
#  'ZmumuJET_GroupedNP_2_1down': [1, 2, 3, 4],
#  'ZmumuJET_GroupedNP_2_1up': [1, 2, 3, 4],
#  'ZmumuJET_GroupedNP_3_1down': [1, 2, 3, 4],
#  'ZmumuJET_GroupedNP_3_1up': [1, 2, 3, 4],
#  'ZmumuJET_JER_DataVsMC_MC16_1down': [1, 2, 3, 4],
#  'ZmumuJET_JER_DataVsMC_MC16_1up': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_1_1down': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_1_1up': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_2_1down': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_2_1up': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_3_1down': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_3_1up': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_4_1down': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_4_1up': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_5_1down': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_5_1up': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_6_1down': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_6_1up': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_7restTerm_1down': [1, 2, 3, 4],
#  'ZmumuJET_JER_EffectiveNP_7restTerm_1up': [1, 2, 3, 4],
#  'ZmumuJET_TILECORR_Uncertainty_1down': [1, 2, 3, 4],
#  'ZmumuJET_TILECORR_Uncertainty_1up': [1, 2, 3, 4],
#  'ZmumuTAUS_TRUEHADTAU_SME_TES_DETECTOR_1down': [1, 2, 3, 4],
#  'ZmumuTAUS_TRUEHADTAU_SME_TES_DETECTOR_1up': [1, 2, 3, 4],
#  'ZmumuTAUS_TRUEHADTAU_SME_TES_INSITUEXP_1down': [1, 2, 3, 4],
#  'ZmumuTAUS_TRUEHADTAU_SME_TES_INSITUEXP_1up': [1, 2, 3, 4],
#  'ZmumuTAUS_TRUEHADTAU_SME_TES_INSITUFIT_1down': [1, 2, 3, 4],
#  'ZmumuTAUS_TRUEHADTAU_SME_TES_INSITUFIT_1up': [1, 2, 3, 4],
#  'ZmumuTAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE_1down': [1, 2, 3, 4],
#  'ZmumuTAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE_1up': [1, 2, 3, 4],
#  'ZmumuTAUS_TRUEHADTAU_SME_TES_PHYSICSLIST_1down': [1, 2, 3, 4],
#  'ZmumuTAUS_TRUEHADTAU_SME_TES_PHYSICSLIST_1up': [1, 2, 3, 4],
#  'VVMET_SoftTrk_ResoPara': [1, 2, 3, 4],
#  'VVMET_SoftTrk_ResoPerp': [1, 2, 3, 4],
#  'VVMET_SoftTrk_Scale_1down': [1, 2, 3, 4],
#  'VVMET_SoftTrk_Scale_1up': [1, 2, 3, 4],
#  'VVMUON_ID_1down': [1, 2, 3, 4],
#  'VVMUON_ID_1up': [1, 2, 3, 4],
#  'VVMUON_MS_1down': [1, 2, 3, 4],
#  'VVMUON_MS_1up': [1, 2, 3, 4],
#  'VVMUON_SAGITTA_RESBIAS_1down': [1, 2, 3, 4],
#  'VVMUON_SAGITTA_RESBIAS_1up': [1, 2, 3, 4],
#  'VVMUON_SAGITTA_RHO_1down': [1, 2, 3, 4],
#  'VVMUON_SAGITTA_RHO_1up': [1, 2, 3, 4],
#  'VVMUON_SCALE_1down': [1, 2, 3, 4],
#  'VVMUON_SCALE_1up': [1, 2, 3, 4],
#  'VVJET_EtaIntercalibration_NonClosure_2018data_1down': [1, 2, 3, 4],
#  'VVJET_EtaIntercalibration_NonClosure_2018data_1up': [1, 2, 3, 4],
#  'VVJET_EtaIntercalibration_NonClosure_highE_1down': [1, 2, 3, 4],
#  'VVJET_EtaIntercalibration_NonClosure_highE_1up': [1, 2, 3, 4],
#  'VVJET_EtaIntercalibration_NonClosure_negEta_1down': [1, 2, 3, 4],
#  'VVJET_EtaIntercalibration_NonClosure_negEta_1up': [1, 2, 3, 4],
#  'VVJET_EtaIntercalibration_NonClosure_posEta_1down': [1, 2, 3, 4],
#  'VVJET_EtaIntercalibration_NonClosure_posEta_1up': [1, 2, 3, 4],
#  'VVJET_Flavor_Response_1down': [1, 2, 3, 4],
#  'VVJET_Flavor_Response_1up': [1, 2, 3, 4],
#  'VVJET_GroupedNP_1_1down': [1, 2, 3, 4],
#  'VVJET_GroupedNP_1_1up': [1, 2, 3, 4],
#  'VVJET_GroupedNP_2_1down': [1, 2, 3, 4],
#  'VVJET_GroupedNP_2_1up': [1, 2, 3, 4],
#  'VVJET_GroupedNP_3_1down': [1, 2, 3, 4],
#  'VVJET_GroupedNP_3_1up': [1, 2, 3, 4],
#  'VVJET_JER_DataVsMC_MC16_1down': [1, 2, 3, 4],
#  'VVJET_JER_DataVsMC_MC16_1up': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_1_1down': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_1_1up': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_2_1down': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_2_1up': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_3_1down': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_3_1up': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_4_1down': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_4_1up': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_5_1down': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_5_1up': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_6_1down': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_6_1up': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_7restTerm_1down': [1, 2, 3, 4],
#  'VVJET_JER_EffectiveNP_7restTerm_1up': [1, 2, 3, 4],
#  'VVJET_TILECORR_Uncertainty_1down': [1, 2, 3, 4],
#  'VVJET_TILECORR_Uncertainty_1up': [1, 2, 3, 4],
#  'VVTAUS_TRUEHADTAU_SME_TES_DETECTOR_1down': [1, 2, 3, 4],
#  'VVTAUS_TRUEHADTAU_SME_TES_DETECTOR_1up': [1, 2, 3, 4],
#  'VVTAUS_TRUEHADTAU_SME_TES_INSITUEXP_1down': [1, 2, 3, 4],
#  'VVTAUS_TRUEHADTAU_SME_TES_INSITUEXP_1up': [1, 2, 3, 4],
#  'VVTAUS_TRUEHADTAU_SME_TES_INSITUFIT_1down': [1, 2, 3, 4],
#  'VVTAUS_TRUEHADTAU_SME_TES_INSITUFIT_1up': [1, 2, 3, 4],
#  'VVTAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE_1down': [1, 2, 3, 4],
#  'VVTAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE_1up': [1, 2, 3, 4],
#  'VVTAUS_TRUEHADTAU_SME_TES_PHYSICSLIST_1down': [1, 2, 3, 4],
#  'VVTAUS_TRUEHADTAU_SME_TES_PHYSICSLIST_1up': [1, 2, 3, 4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_ISO_STAT_1down_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_ISO_STAT_1down_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_ISO_STAT_1up_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_ISO_STAT_1up_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_ISO_SYS_1down_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_ISO_SYS_1down_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_ISO_SYS_1up_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_ISO_SYS_1up_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_RECO_STAT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_RECO_STAT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_RECO_STAT_LOWPT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_RECO_STAT_LOWPT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_RECO_SYS_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_RECO_SYS_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_RECO_SYS_LOWPT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_RECO_SYS_LOWPT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_TTVA_STAT_1down_MuEffSF_TTVA': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_TTVA_STAT_1up_MuEffSF_TTVA': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_TTVA_SYS_1down_MuEffSF_TTVA': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_TTVA_SYS_1up_MuEffSF_TTVA': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_TrigStatUncertainty_1down_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_TrigStatUncertainty_1down_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_TrigStatUncertainty_1up_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_TrigStatUncertainty_1up_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_TrigSystUncertainty_1down_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_TrigSystUncertainty_1down_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_TrigSystUncertainty_1up_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_muon_0_MUON_EFF_TrigSystUncertainty_1up_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_B_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_B_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_B_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_B_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_B_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_B_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_B_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_B_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_B_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_B_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_B_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_B_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_3_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_3_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_3_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_C_3_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_3_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_3_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_3_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_Eigen_Light_3_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_extrapolation_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_extrapolation_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_extrapolation_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_extrapolation_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_extrapolation_from_charm_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_extrapolation_from_charm_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_extrapolation_from_charm_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_FT_EFF_extrapolation_from_charm_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_JET_JvtEfficiency_1down_central_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_JET_JvtEfficiency_1down_central_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_JET_JvtEfficiency_1up_central_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_JET_JvtEfficiency_1up_central_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_JET_fJvtEfficiency_1down_forward_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_JET_fJvtEfficiency_1down_forward_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_JET_fJvtEfficiency_1up_forward_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_jet_JET_fJvtEfficiency_1up_forward_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1down_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1down_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1up_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1up_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1down_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1down_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1up_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1up_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1down_TauEffSF_reco': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1down_TauEffSF_selection': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1up_TauEffSF_reco': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL1_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1up_TauEffSF_selection': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_ISO_STAT_1down_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_ISO_STAT_1down_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_ISO_STAT_1up_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_ISO_STAT_1up_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_ISO_SYS_1down_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_ISO_SYS_1down_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_ISO_SYS_1up_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_ISO_SYS_1up_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_RECO_STAT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_RECO_STAT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_RECO_STAT_LOWPT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_RECO_STAT_LOWPT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_RECO_SYS_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_RECO_SYS_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_RECO_SYS_LOWPT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_RECO_SYS_LOWPT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_TTVA_STAT_1down_MuEffSF_TTVA': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_TTVA_STAT_1up_MuEffSF_TTVA': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_TTVA_SYS_1down_MuEffSF_TTVA': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_TTVA_SYS_1up_MuEffSF_TTVA': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_TrigStatUncertainty_1down_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_TrigStatUncertainty_1down_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_TrigStatUncertainty_1up_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_TrigStatUncertainty_1up_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_TrigSystUncertainty_1down_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_TrigSystUncertainty_1down_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_TrigSystUncertainty_1up_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_muon_0_MUON_EFF_TrigSystUncertainty_1up_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_B_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_B_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_B_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_B_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_B_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_B_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_B_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_B_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_B_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_B_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_B_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_B_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_3_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_3_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_3_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_C_3_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_3_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_3_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_3_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_Eigen_Light_3_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_extrapolation_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_extrapolation_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_extrapolation_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_extrapolation_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_extrapolation_from_charm_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_extrapolation_from_charm_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_extrapolation_from_charm_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_FT_EFF_extrapolation_from_charm_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_JET_JvtEfficiency_1down_central_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_JET_JvtEfficiency_1down_central_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_JET_JvtEfficiency_1up_central_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_JET_JvtEfficiency_1up_central_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_JET_fJvtEfficiency_1down_forward_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_JET_fJvtEfficiency_1down_forward_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_JET_fJvtEfficiency_1up_forward_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_jet_JET_fJvtEfficiency_1up_forward_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1down_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1down_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1up_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1up_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1down_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1down_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1up_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1up_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1down_TauEffSF_reco': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1down_TauEffSF_selection': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1up_TauEffSF_reco': [1,
#   2,
#   3,
#   4],
#  'Signal_SherpaNOMINAL2_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1up_TauEffSF_selection': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_ISO_STAT_1down_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_ISO_STAT_1down_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_ISO_STAT_1up_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_ISO_STAT_1up_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_ISO_SYS_1down_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_ISO_SYS_1down_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_ISO_SYS_1up_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_ISO_SYS_1up_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_RECO_STAT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_RECO_STAT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_RECO_STAT_LOWPT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_RECO_STAT_LOWPT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_RECO_SYS_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_RECO_SYS_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_RECO_SYS_LOWPT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_RECO_SYS_LOWPT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_TTVA_STAT_1down_MuEffSF_TTVA': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_TTVA_STAT_1up_MuEffSF_TTVA': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_TTVA_SYS_1down_MuEffSF_TTVA': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_TTVA_SYS_1up_MuEffSF_TTVA': [1, 2, 3, 4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_TrigStatUncertainty_1down_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_TrigStatUncertainty_1down_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_TrigStatUncertainty_1up_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_TrigStatUncertainty_1up_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_TrigSystUncertainty_1down_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_TrigSystUncertainty_1down_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_TrigSystUncertainty_1up_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_muon_0_MUON_EFF_TrigSystUncertainty_1up_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_B_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_B_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_B_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_B_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_B_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_B_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_B_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_B_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_B_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_B_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_B_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_B_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_3_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_3_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_3_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_C_3_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_3_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_3_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_3_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_Eigen_Light_3_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_extrapolation_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_extrapolation_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_extrapolation_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_extrapolation_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_extrapolation_from_charm_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_extrapolation_from_charm_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_extrapolation_from_charm_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_FT_EFF_extrapolation_from_charm_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_JET_JvtEfficiency_1down_central_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_JET_JvtEfficiency_1down_central_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_JET_JvtEfficiency_1up_central_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_JET_JvtEfficiency_1up_central_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_JET_fJvtEfficiency_1down_forward_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_JET_fJvtEfficiency_1down_forward_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_JET_fJvtEfficiency_1up_forward_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_jet_JET_fJvtEfficiency_1up_forward_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1down_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1down_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1up_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1up_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1down_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1down_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1up_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1up_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1down_TauEffSF_reco': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1down_TauEffSF_selection': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1up_TauEffSF_reco': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL1_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1up_TauEffSF_selection': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_ISO_STAT_1down_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_ISO_STAT_1down_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_ISO_STAT_1up_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_ISO_STAT_1up_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_ISO_SYS_1down_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_ISO_SYS_1down_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_ISO_SYS_1up_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_ISO_SYS_1up_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_RECO_STAT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_RECO_STAT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_RECO_STAT_LOWPT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_RECO_STAT_LOWPT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_RECO_SYS_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_RECO_SYS_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_RECO_SYS_LOWPT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_RECO_SYS_LOWPT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'Signal_PoPyNOMINAL2_muon_0_MUON_EFF_TTVA_STAT_1down_MuEffSF_TTVA': [1,
#   2,
#   3,
#   4],
# ...
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_RECO_STAT_LOWPT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_RECO_STAT_LOWPT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_RECO_SYS_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_RECO_SYS_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_RECO_SYS_LOWPT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_RECO_SYS_LOWPT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_TTVA_STAT_1down_MuEffSF_TTVA': [1, 2, 3, 4],
#  'VVNOMINAL1_muon_0_MUON_EFF_TTVA_STAT_1up_MuEffSF_TTVA': [1, 2, 3, 4],
#  'VVNOMINAL1_muon_0_MUON_EFF_TTVA_SYS_1down_MuEffSF_TTVA': [1, 2, 3, 4],
#  'VVNOMINAL1_muon_0_MUON_EFF_TTVA_SYS_1up_MuEffSF_TTVA': [1, 2, 3, 4],
#  'VVNOMINAL1_muon_0_MUON_EFF_TrigStatUncertainty_1down_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_TrigStatUncertainty_1down_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_TrigStatUncertainty_1up_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_TrigStatUncertainty_1up_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_TrigSystUncertainty_1down_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_TrigSystUncertainty_1down_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_TrigSystUncertainty_1up_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_muon_0_MUON_EFF_TrigSystUncertainty_1up_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_B_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_B_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_B_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_B_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_B_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_B_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_B_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_B_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_B_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_B_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_B_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_B_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_3_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_3_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_3_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_C_3_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_3_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_3_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_3_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_Eigen_Light_3_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_extrapolation_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_extrapolation_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_extrapolation_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_extrapolation_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_extrapolation_from_charm_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_extrapolation_from_charm_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_extrapolation_from_charm_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_FT_EFF_extrapolation_from_charm_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_JET_JvtEfficiency_1down_central_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_JET_JvtEfficiency_1down_central_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_JET_JvtEfficiency_1up_central_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_JET_JvtEfficiency_1up_central_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_JET_fJvtEfficiency_1down_forward_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_JET_fJvtEfficiency_1down_forward_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_JET_fJvtEfficiency_1up_forward_jets_global_effSF_JVT': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_jet_JET_fJvtEfficiency_1up_forward_jets_global_ineffSF_JVT': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1down_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1down_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1up_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_STAT_1up_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1down_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1down_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1up_TauEffSF_LooseEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_tau_0_TAUS_TRUEELECTRON_EFF_ELEBDT_SYST_1up_TauEffSF_MediumEleBDT_electron': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1down_TauEffSF_reco': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1down_TauEffSF_selection': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1up_TauEffSF_reco': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL1_tau_0_TAUS_TRUEHADTAU_EFF_RECO_TOTAL_1up_TauEffSF_selection': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_ISO_STAT_1down_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_ISO_STAT_1down_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_ISO_STAT_1up_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_ISO_STAT_1up_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_ISO_SYS_1down_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_ISO_SYS_1down_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_ISO_SYS_1up_MuEffSF_IsoLoose_FixedRad': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_ISO_SYS_1up_MuEffSF_IsoTightTrackOnly_FixedRad': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_RECO_STAT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_RECO_STAT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_RECO_STAT_LOWPT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_RECO_STAT_LOWPT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_RECO_SYS_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_RECO_SYS_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_RECO_SYS_LOWPT_1down_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_RECO_SYS_LOWPT_1up_MuEffSF_Reco_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_TTVA_STAT_1down_MuEffSF_TTVA': [1, 2, 3, 4],
#  'VVNOMINAL2_muon_0_MUON_EFF_TTVA_STAT_1up_MuEffSF_TTVA': [1, 2, 3, 4],
#  'VVNOMINAL2_muon_0_MUON_EFF_TTVA_SYS_1down_MuEffSF_TTVA': [1, 2, 3, 4],
#  'VVNOMINAL2_muon_0_MUON_EFF_TTVA_SYS_1up_MuEffSF_TTVA': [1, 2, 3, 4],
#  'VVNOMINAL2_muon_0_MUON_EFF_TrigStatUncertainty_1down_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_TrigStatUncertainty_1down_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_TrigStatUncertainty_1up_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_TrigStatUncertainty_1up_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_TrigSystUncertainty_1down_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_TrigSystUncertainty_1down_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_TrigSystUncertainty_1up_MuEffSF_HLT_mu20_iloose_L1MU15_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_muon_0_MUON_EFF_TrigSystUncertainty_1up_MuEffSF_HLT_mu26_ivarmedium_OR_HLT_mu50_QualMedium': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_B_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_B_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_B_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_B_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_B_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_B_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_B_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_B_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_B_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_B_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_B_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_B_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_3_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_3_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_3_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_C_3_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_Light_0_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_Light_0_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_Light_0_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_Light_0_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_Light_1_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_Light_1_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_Light_1_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_Light_1_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_Light_2_1down_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_Light_2_1down_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_Light_2_1up_global_effSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  'VVNOMINAL2_jet_FT_EFF_Eigen_Light_2_1up_global_ineffSF_MV2c10_FixedCutBEff_85': [1,
#   2,
#   3,
#   4],
#  ...}
