# %%
import ROOT
from ROOT import gStyle
import numpy as np

def biner(o_bin,m_bin,f_bin,f_step,l_step):
    a=np.arange(o_bin,m_bin,f_step)
    b=np.arange(m_bin,f_bin+l_step,l_step)
    return np.concatenate((a,b))

def normalization(hist_list):
    for hist in hist_list:
        for i in range(0,len(rebining)):
            value=hist.GetBinContent(i)
            error=hist.GetBinError(i)
            sf=hist.GetBinWidth(i)/5.0    
            hist.SetBinContent(i,value/sf)
            hist.SetBinError(i,error/sf)
# Out:
# Welcome to JupyROOT 6.20/04

# %%
histos={
       "tau_pt_btag_iso_rnn_ptmu_omega_mreco_inside":["yy",120,5,20,"Events/5 GeV","p_{T}(#tau)(GeV)(i)",1.2],
       "tau_pt_btag_iso_rnn_ptmu_omega_mreco_outside":["yy",120,5,20,"Events/5 GeV","p_{T}(#tau)(GeV)(o)",1.2],
        "lep_pt0_btag_iso_rnn_ptmu_omega_mreco":["yy",120,5,20,"Events/5 GeV","p_{T}(#mu)(GeV)",1.2],
       "MET_btag_iso_rnn_ptmu_omega_mreco":["yy",120,5,20,"Events/5 GeV","MET(GeV)",1.2],
       "Z_pt_cuts_inside":["yy",180,10,20,"Events/5 GeV","p_{T}(Z)(GeV)(i)",1.2],
       "Z_pt_cuts_outside":["yy",180,10,20,"Events/5 GeV","p_{T}(Z)(GeV)(o)",1.2],
       "transverse_lepton_met_mass_btag_iso_rnn_ptmu_omega_mreco":["yy",120,5,20,"Events/5 GeV","m_{T}(#mu)(GeV)",1.2,100],
       "delta_phi_cuts_butphi":["n",1,1,1,"Events/0.1","#Delta#varphi(#tau,#mu)",1.4,2.3],
       "delta_phi_cuts":["n",1,1,1,"Events/0.1","#Delta#varphi(#tau,#mu)",1.4,2.3],
        "ratio_ptjet_zpt_cuts":["n",2,1,1,"Events/0.1","#Delta#varphi(#tau,#mu)",1.4],
        "ratio_lpt_tpt_cuts":["n",2,1,1,"Events/0.1","#Delta#varphi(#tau,#mu)",1.4],
        
       "reco_mass_btag_iso_rnn_ptmu_omega_tpt":["yy",120,5,20,"Events/5 GeV","m_{reco}(GeV)(i)",1.2],
       "reco_mass_met_outside_btag_iso_rnn_ptmu_omega_tpt":["yy",120,5,20,"Events/5 GeV","m_{reco}(GeV)(o)",1.2],
       "tau_pt_btag_iso_rnn_ptmu_omega_mreco_tpt_inside":["yy",120,5,20,"Events/5 GeV","p_{T}(#tau)(GeV)(i)",1.2],
       "tau_pt_btag_iso_rnn_ptmu_omega_mreco_tpt_outside":["yy",120,5,20,"Events/5 GeV","p_{T}(#tau)(GeV)(o)",1.2],
        "lep_pt0_btag_iso_rnn_ptmu_omega_mreco_tpt":["yy",120,5,20,"Events/5 GeV","p_{T}(#mu)(GeV)",1.2],
       "MET_btag_iso_rnn_ptmu_omega_mreco_tpt":["yy",120,5,20,"Events/5 GeV","MET(GeV)",1.2],
       "Z_pt_cuts_tpt_inside":["yy",180,10,20,"Events/5 GeV","p_{T}(Z)(GeV)(i)",1.2],
       "Z_pt_cuts_tpt_outside":["yy",180,10,20,"Events/5 GeV","p_{T}(Z)(GeV)(o)",1.2],
       "transverse_lepton_met_mass_btag_iso_rnn_ptmu_omega_mreco_tpt":["yy",120,5,20,"Events/5 GeV","m_{T}(#mu)(GeV)",1.2,100],
       "omega_btag_iso_rnn_ptmu_mreco_tpt":["yn",1,0.2,0.2,"Events/0.2","#Omega",1.2],
       "delta_phi_cuts_butphi":["n",1,1,1,"Events/0.1","#Delta#varphi(#tau,#mu)",1.4,2.3],
       "delta_phi_cuts_tpt":["n",1,1,1,"Events/0.1","#Delta#varphi(#tau,#mu)",1.4,2.3],
       "rnn_score_1prong_btag_iso_ptmu_omega_mreco_tpt":["yn",0.7,0.02,0.02,"Events/0.01","jetRNNScore",1.4],
       "rnn_score_3prong_btag_iso_ptmu_omega_mreco_tpt":["yn",0.7,0.02,0.02,"Events/0.01","jetRNNScore",1.4],
        "ratio_ptjet_zpt_cuts_tpt":["n",2,1,1,"Events/0.1","#Delta#varphi(#tau,#mu)",1.4],
        "ratio_lpt_tpt_cuts_tpt":["n",2,1,1,"Events/0.1","#Delta#varphi(#tau,#mu)",1.4]}

# %%
#CALCULATION OF RQCD
for k in histos:
    rebin=histos[k][0]
    histo=k

    MC_CR_OS=ROOT.TFile.Open("CR_OS/MC.root","READ")
    Data_CR_OS = ROOT.TFile.Open("CR_OS/Data.root","READ")
    MC_CR_SS=ROOT.TFile.Open("CR_SS/MC.root","READ")
    Data_CR_SS = ROOT.TFile.Open("CR_SS/Data.root","READ")

    a=k

    mc_cr_os=MC_CR_OS.Get(histo)
    data_cr_os=Data_CR_OS.Get(histo)
    mc_cr_ss=MC_CR_SS.Get(histo)
    data_cr_ss=Data_CR_SS.Get(histo)

    mc_cr_os.SetDirectory(0)
    data_cr_os.SetDirectory(0)
    mc_cr_ss.SetDirectory(0)
    data_cr_ss.SetDirectory(0)

    MC_CR_OS.Close()
    Data_CR_OS.Close()
    MC_CR_SS.Close()
    Data_CR_SS.Close()
    print(a)
    print("ANTES")
    print(data_cr_os.Integral())
    data_cr_os.Add(mc_cr_os,-1)
    data_cr_ss.Add(mc_cr_ss,-1)
    print("DESPUES")
    print(data_cr_os.Integral())
    RQCD=data_cr_os.Integral()/data_cr_ss.Integral()

    # HISTOGRAM FOR SR_OS

    MC_SR_OS=ROOT.TFile.Open("SR_OS/MC.root","READ")
    Data_SR_OS = ROOT.TFile.Open("SR_OS/Data.root","READ")
    MC_SR_SS=ROOT.TFile.Open("SR_SS/MC.root","READ")
    Data_SR_SS = ROOT.TFile.Open("SR_SS/Data.root","READ")

    mc_sr_os=MC_SR_OS.Get(histo)
    data_sr_os=Data_SR_OS.Get(histo)
    mc_sr_ss=MC_SR_SS.Get(histo)
    data_sr_ss=Data_SR_SS.Get(histo)

    mc_sr_os.SetDirectory(0)
    data_sr_os.SetDirectory(0)
    mc_sr_ss.SetDirectory(0)
    data_sr_ss.SetDirectory(0)

    MC_SR_OS.Close()
    Data_SR_OS.Close()
    MC_SR_SS.Close()
    Data_SR_SS.Close()

    ob=data_sr_ss.GetNbinsX()
    s=data_sr_ss.GetXaxis().GetBinLowEdge(1)
    e=data_sr_ss.GetXaxis().GetBinUpEdge(data_sr_ss.GetNbinsX())
    n=5
    if rebin=="yy" or rebin=="yn":
        rebining=biner(s,histos[k][1],e,histos[k][2],histos[k][3])
        nb=len(rebining)-1
        mc_sr_ss=mc_sr_ss.Rebin(nb,"mc_sr_ss",rebining)
        data_sr_ss=data_sr_ss.Rebin(nb,"data_sr_ss",rebining)


    MJ_BG=data_sr_ss.Clone()
    MJ_BG.Add(mc_sr_ss,-1)
    MJ_BG.Scale(RQCD)

    # SAVING MJ BG HISTOGRAM

    ##############################
    file=ROOT.TFile.Open("SR_OS/MJ.root","update")
    MJ_BG.Write(a)
    file.Close()
    ##############################

    #PLOTS

    Data = ROOT.TFile.Open("SR_OS/Data.root","READ")
    Signal=ROOT.TFile.Open("SR_OS/Signal.root","READ")
    VV=ROOT.TFile.Open("SR_OS/VV.root","READ")
    Wjets=ROOT.TFile.Open("SR_OS/Wjets.root","READ")
    Zjets=ROOT.TFile.Open("SR_OS/Zjet.root","READ")
    Ttbar=ROOT.TFile.Open("SR_OS/ttbar.root","READ")
    SingleTop=ROOT.TFile.Open("SR_OS/singletop.root","READ")
    MJ=ROOT.TFile.Open("SR_OS/MJ.root","READ")
    Error=ROOT.TFile.Open("SR_OS/MC.root","READ")

    data=Data.Get(a)
    signal=Signal.Get(a)
    vv=VV.Get(a)
    w=Wjets.Get(a)
    z=Zjets.Get(a)
    tt=Ttbar.Get(a)
    t=SingleTop.Get(a)
    mj=MJ.Get(a)
    error=Error.Get(a)

    signal.SetDirectory(0)
    data.SetDirectory(0)
    vv.SetDirectory(0)
    w.SetDirectory(0)
    z.SetDirectory(0)
    tt.SetDirectory(0)
    t.SetDirectory(0)
    mj.SetDirectory(0)
    error.SetDirectory(0)

    Signal.Close()
    Data.Close()
    VV.Close()
    Wjets.Close()
    Zjets.Close()
    Ttbar.Close()
    SingleTop.Close()
    MJ.Close()
    Error.Close()

    hs = ROOT.THStack("hs","")
    if rebin=="yy" or rebin=="yn":
        signal=signal.Rebin(nb,"signal",rebining)
        data=data.Rebin(nb,"data",rebining)
        vv=vv.Rebin(nb,"vv",rebining)
        tt=tt.Rebin(nb,"tt",rebining)
        t=t.Rebin(nb,"t",rebining)
        z=z.Rebin(nb,"z",rebining)
        w=w.Rebin(nb,"w",rebining)
        error=error.Rebin(nb,"error",rebining)

    ratio=w.Clone()
    lista = ROOT.TList()
    lista.Add(mj)
    lista.Add(z)
    lista.Add(vv)
    lista.Add(tt)
    lista.Add(t)
    lista.Add(signal)
    ratio.Merge(lista)
    ratio.Divide(data)

    if rebin=="yy":
        hist_list=[signal,data,vv,tt,t,z,w,mj,error]
        normalization(hist_list)

    w.SetFillColor(ROOT.kGreen)
    w.SetLineColor(ROOT.kGreen)
    z.SetFillColor(ROOT.kRed)
    z.SetLineColor(ROOT.kRed)
    vv.SetFillColor(ROOT.kBlue)
    vv.SetLineColor(ROOT.kBlue)
    tt.SetFillColor(ROOT.kYellow)
    tt.SetLineColor(ROOT.kYellow)
    t.SetFillColor(ROOT.kCyan)
    t.SetLineColor(ROOT.kCyan)
    mj.SetLineColor(ROOT.kMagenta)
    mj.SetFillColor(ROOT.kMagenta)
    data.SetLineColor(ROOT.kBlack)
    error.SetFillColor(40)
    
    '''
    data.GetXaxis().SetRangeUser(40,250)
    vv.GetXaxis().SetRangeUser(40,250)
    w.GetXaxis().SetRangeUser(40,250)
    z.GetXaxis().SetRangeUser(40,250)
    tt.GetXaxis().SetRangeUser(40,250)
    t.GetXaxis().SetRangeUser(40,250)
    mj.GetXaxis().SetRangeUser(40,250)
    signal.GetXaxis().SetRangeUser(40,250)
    '''
    hs.Add(vv)
    hs.Add(w)
    hs.Add(z)
    hs.Add(tt)
    hs.Add(t)
    hs.Add(mj)
    hs.Add(signal)
    
    error.Add(mj,1)

    gStyle.SetOptStat(1111111)

    canvas3 = ROOT.TCanvas("canvas3")
    canvas3.cd()

    pad1 = ROOT . TPad (" pad1 "," pad1 " ,0 ,0.35 ,1 ,1)

    pad1.Draw ()
    pad1.cd ()

    gStyle.SetStatY(0.9);                
    gStyle.SetStatX(0.9);
    gStyle.SetStatW(0.1);                
    gStyle.SetStatH(0.1);
    if "rnn_score" in k:
        pad1.SetLogy(1)


    data.Draw("pe")
    error.Draw("E2 same")
    hs.Draw("HIST same")
    data.Draw("pe same")
    data.GetXaxis().Draw()
    pad1.RedrawAxis()


    data.SetTitle("Hola")
    l=ROOT.TLatex()
    l.SetNDC ()
    l.DrawLatex(0.6,0.80,"Z#rightarrow#tau#tau#rightarrow#tau#mu")
    
    if len(histos[k])>7:
        e=histos[k][7]

    pad1.SetTicks(1,1)
    pad1.Update()
    data . GetYaxis (). SetRangeUser (1 ,histos[k][6]*data.GetBinContent(data.GetMaximumBin()))
    data . GetXaxis (). SetRangeUser (s ,e)
    data . GetYaxis (). SetTitle (histos[k][4])
    data . GetXaxis (). SetTitle (histos[k][5])

    hs . GetXaxis (). SetRangeUser (s ,e)
    legend = ROOT . TLegend (0.7 ,0.68 ,0.8 ,0.88)
    legend . AddEntry ( vv ,"Diboson")
    legend . AddEntry ( data ," Data ")
    legend . AddEntry ( signal ," Signal ")
    legend . AddEntry ( w ," W+jets ")
    legend . AddEntry ( z ," Z+jet ")
    legend . AddEntry ( t ," Single top ")
    legend . AddEntry ( tt ," ttbar ")
    legend . AddEntry ( mj,"MJ")

    legend . SetLineWidth (0)
    legend . Draw ()



    hs.SetTitle(a)

    canvas3.cd()
    pad2 = ROOT . TPad (" pad2 "," pad2 " ,0 ,0.05 ,1 ,0.35)
    pad2.Draw ()
    pad2.cd ()
    ratio.Draw ("pe")
    ratio.SetStats(0)
    ratio . GetYaxis (). SetRangeUser (0 ,2.0)
    ratio . GetXaxis (). SetRangeUser (s ,e)
    ratio . GetYaxis (). SetTitle ("MC/DATA")
    ratio . GetYaxis (). SetTitleSize (0.15)
    ratio . GetYaxis (). SetTitleOffset (0.25)
    line = ROOT . TLine (s ,1 ,e,1)
    line . SetLineColor ( ROOT . kBlack )
    line . SetLineWidth (2)
    line . Draw (" same ")


    canvas3.Print(a+".pdf")
# Out:
# tau_pt_btag_iso_rnn_ptmu_omega_mreco_inside
# ANTES
# 31217.0
# DESPUES
# 30500.41400308907
# tau_pt_btag_iso_rnn_ptmu_omega_mreco_outside
# ANTES
# 16747.0
# DESPUES
# 16270.293182419438
# lep_pt0_btag_iso_rnn_ptmu_omega_mreco
# ANTES
# 341647.0
# DESPUES
# 242625.97191286087
# MET_btag_iso_rnn_ptmu_omega_mreco
# ANTES
# 341886.0
# DESPUES
# 242763.16961443424
# Z_pt_cuts_inside
# ANTES
# 218162.0
# DESPUES
# 160139.1728694439
# Z_pt_cuts_outside
# ANTES
# 123417.0
# DESPUES
# 82486.47379425168
# transverse_lepton_met_mass_btag_iso_rnn_ptmu_omega_mreco
# ANTES
# 341977.0
# DESPUES
# 242804.62739482336
# delta_phi_cuts_butphi
# ANTES
# 10973.0
# DESPUES
# 10677.334897994995
# delta_phi_cuts
# ANTES
# 341977.0
# DESPUES
# 242804.6328125
# ratio_ptjet_zpt_cuts
# ANTES
# 341761.0
# DESPUES
# 242622.53071784973
# ratio_lpt_tpt_cuts
# ANTES
# 339613.0
# DESPUES
# 241943.06139039993
# reco_mass_btag_iso_rnn_ptmu_omega_tpt
# ANTES
# 28244.0
# DESPUES
# 27621.74929189682
# reco_mass_met_outside_btag_iso_rnn_ptmu_omega_tpt
# ANTES
# 10520.0
# DESPUES
# 10213.531484127045
# tau_pt_btag_iso_rnn_ptmu_omega_mreco_tpt_inside
# ANTES
# 51479.0
# DESPUES
# 38699.47637844086
# tau_pt_btag_iso_rnn_ptmu_omega_mreco_tpt_outside
# ANTES
# 22834.0
# DESPUES
# 15954.703637480736
# lep_pt0_btag_iso_rnn_ptmu_omega_mreco_tpt
# ANTES
# 74456.0
# DESPUES
# 54744.3326420784
# MET_btag_iso_rnn_ptmu_omega_mreco_tpt
# ANTES
# 74521.0
# DESPUES
# 54802.991677075624
# Z_pt_cuts_tpt_inside
# ANTES
# 51465.0
# DESPUES
# 38740.33813393116
# Z_pt_cuts_tpt_outside
# ANTES
# 22810.0
# DESPUES
# 15956.111109882593
# transverse_lepton_met_mass_btag_iso_rnn_ptmu_omega_mreco_tpt
# ANTES
# 74566.0
# DESPUES
# 54821.71073456691
# omega_btag_iso_rnn_ptmu_mreco_tpt
# ANTES
# 20928.0
# DESPUES
# 18855.98540663719
# delta_phi_cuts_tpt
# ANTES
# 74566.0
# DESPUES
# 54821.7112121582
# rnn_score_1prong_btag_iso_ptmu_omega_mreco_tpt
# ANTES
# 3066.0
# DESPUES
# 2899.0701026320457
# rnn_score_3prong_btag_iso_ptmu_omega_mreco_tpt
# ANTES
# 6369.0
# DESPUES
# 6233.580864973366
# ratio_ptjet_zpt_cuts_tpt
# ANTES
# 74544.0
# DESPUES
# 54806.56584966183
# ratio_lpt_tpt_cuts_tpt
# ANTES
# 74518.0
# DESPUES
# 54799.097301483154
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_pt_btag_iso_rnn_ptmu_omega_mreco_inside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_pt_btag_iso_rnn_ptmu_omega_mreco_outside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file lep_pt0_btag_iso_rnn_ptmu_omega_mreco.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file MET_btag_iso_rnn_ptmu_omega_mreco.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file Z_pt_cuts_inside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file Z_pt_cuts_outside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file transverse_lepton_met_mass_btag_iso_rnn_ptmu_omega_mreco.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file delta_phi_cuts_butphi.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file delta_phi_cuts.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file ratio_ptjet_zpt_cuts.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file ratio_lpt_tpt_cuts.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file reco_mass_btag_iso_rnn_ptmu_omega_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file reco_mass_met_outside_btag_iso_rnn_ptmu_omega_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_pt_btag_iso_rnn_ptmu_omega_mreco_tpt_inside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_pt_btag_iso_rnn_ptmu_omega_mreco_tpt_outside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file lep_pt0_btag_iso_rnn_ptmu_omega_mreco_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file MET_btag_iso_rnn_ptmu_omega_mreco_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file Z_pt_cuts_tpt_inside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file Z_pt_cuts_tpt_outside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file transverse_lepton_met_mass_btag_iso_rnn_ptmu_omega_mreco_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file omega_btag_iso_rnn_ptmu_mreco_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file delta_phi_cuts_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file rnn_score_1prong_btag_iso_ptmu_omega_mreco_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file rnn_score_3prong_btag_iso_ptmu_omega_mreco_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file ratio_ptjet_zpt_cuts_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file ratio_lpt_tpt_cuts_tpt.pdf has been created

# %%
file=ROOT.TFile.Open("SR_OS/MJ.root","update")
MJ_BG.Write(a)
file.Close()

# %%
Data = ROOT.TFile.Open("SR_OS/Data.root","READ")
Signal=ROOT.TFile.Open("SR_OS/Signal.root","READ")
VV=ROOT.TFile.Open("SR_OS/VV.root","READ")
Wjets=ROOT.TFile.Open("SR_OS/Wjets.root","READ")
Zjets=ROOT.TFile.Open("SR_OS/Zjet.root","READ")
Ttbar=ROOT.TFile.Open("SR_OS/ttbar.root","READ")
SingleTop=ROOT.TFile.Open("SR_OS/singletop.root","READ")
MJ=ROOT.TFile.Open("SR_OS/MJ.root","READ")

data=Data.Get(a)
signal=Signal.Get(a)
vv=VV.Get(a)
w=Wjets.Get(a)
z=Zjets.Get(a)
tt=Ttbar.Get(a)
t=SingleTop.Get(a)
mj=MJ.Get(a)

signal.SetDirectory(0)
data.SetDirectory(0)
vv.SetDirectory(0)
w.SetDirectory(0)
z.SetDirectory(0)
tt.SetDirectory(0)
t.SetDirectory(0)
mj.SetDirectory(0)

Signal.Close()
Data.Close()
VV.Close()
Wjets.Close()
Zjets.Close()
Ttbar.Close()
SingleTop.Close()
MJ.Close()

hs = ROOT.THStack("hs","")
if rebin=="y":
    signal=signal.Rebin(nb,"signal",rebining)
    data=data.Rebin(nb,"data",rebining)
    vv=vv.Rebin(nb,"vv",rebining)
    tt=tt.Rebin(nb,"tt",rebining)
    t=t.Rebin(nb,"t",rebining)
    z=z.Rebin(nb,"z",rebining)
    w=w.Rebin(nb,"w",rebining)

ratio=w.Clone()
lista = ROOT.TList()
lista.Add(mj)
lista.Add(z)
lista.Add(vv)
lista.Add(tt)
lista.Add(t)
lista.Add(signal)
ratio.Merge(lista)
ratio.Divide(data)

if rebin=="y":
    hist_list=[signal,data,vv,tt,t,z,w,mj]
    normalization(hist_list)

w.SetFillColor(ROOT.kGreen)
w.SetLineColor(ROOT.kGreen)
z.SetFillColor(ROOT.kRed)
z.SetLineColor(ROOT.kRed)
vv.SetFillColor(ROOT.kBlue)
vv.SetLineColor(ROOT.kBlue)
tt.SetFillColor(ROOT.kYellow)
tt.SetLineColor(ROOT.kYellow)
t.SetFillColor(ROOT.kCyan)
t.SetLineColor(ROOT.kCyan)
mj.SetLineColor(ROOT.kMagenta)
mj.SetFillColor(ROOT.kMagenta)
data.SetLineColor(ROOT.kBlack)
'''
data.GetXaxis().SetRangeUser(40,250)
vv.GetXaxis().SetRangeUser(40,250)
w.GetXaxis().SetRangeUser(40,250)
z.GetXaxis().SetRangeUser(40,250)
tt.GetXaxis().SetRangeUser(40,250)
t.GetXaxis().SetRangeUser(40,250)
mj.GetXaxis().SetRangeUser(40,250)
signal.GetXaxis().SetRangeUser(40,250)
'''
hs.Add(vv)
hs.Add(w)
hs.Add(z)
hs.Add(tt)
hs.Add(t)
hs.Add(mj)
hs.Add(signal)





gStyle.SetOptStat(1111111)


canvas3 = ROOT.TCanvas("canvas3")
canvas3.cd()

pad1 = ROOT . TPad (" pad1 "," pad1 " ,0 ,0.35 ,1 ,1)

pad1.Draw ()
pad1.cd ()

gStyle.SetStatY(0.9);                
gStyle.SetStatX(0.9);
gStyle.SetStatW(0.1);                
gStyle.SetStatH(0.1); 
pad1.SetLogy(0)


data.Draw("pe")
hs.Draw("HIST same")
data.Draw("pe same")
data.GetXaxis().Draw()
pad1.RedrawAxis()
               

data.SetTitle("Hola")
l=ROOT.TLatex()
l.SetNDC ()
l.DrawLatex(0.6,0.80,"Z#rightarrow#tau#tau#rightarrow#tau#mu")
    
pad1.SetTicks(1,1)
pad1.Update()
data . GetYaxis (). SetRangeUser (1 ,1.4*data.GetBinContent(data.GetMaximumBin()))
data . GetXaxis (). SetRangeUser (-2 ,e)
data . GetYaxis (). SetTitle ("Events/0.01")
data . GetXaxis (). SetTitle ("jetRNNScore")

hs . GetXaxis (). SetRangeUser (s ,e)
legend = ROOT . TLegend (0.7 ,0.68 ,0.8 ,0.88)
legend . AddEntry ( vv ,"Diboson")
legend . AddEntry ( data ," Data ")
legend . AddEntry ( signal ," Signal ")
legend . AddEntry ( w ," W+jets ")
legend . AddEntry ( z ," Z+jet ")
legend . AddEntry ( t ," Single top ")
legend . AddEntry ( tt ," ttbar ")
legend . AddEntry ( mj,"MJ")

legend . SetLineWidth (0)
legend . Draw ()



hs.SetTitle(a)

canvas3.cd()
pad2 = ROOT . TPad (" pad2 "," pad2 " ,0 ,0.05 ,1 ,0.35)
pad2.Draw ()
pad2.cd ()
ratio.Draw ("pe")
ratio.SetStats(0)
ratio . GetYaxis (). SetRangeUser (0 ,2.0)
ratio . GetXaxis (). SetRangeUser (s ,e)
ratio . GetYaxis (). SetTitle ("MC/DATA")
ratio . GetYaxis (). SetTitleSize (0.15)
ratio . GetYaxis (). SetTitleOffset (0.25)
line = ROOT . TLine (s ,1 ,e,1)
line . SetLineColor ( ROOT . kBlack )
line . SetLineWidth (2)
line . Draw (" same ")


canvas3.Print(a+".pdf")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file rnn_score_3prong_btag_iso_ptmu_omega_mreco.pdf has been created

# %% [markdown]
# ##

# %%
dic={"uno":[1,2,3],"dos":[5,6,7],"tres":[8,9,0]}

# %%
for i in dic:
    print(dic[i])
# Out:
# [1, 2, 3]
# [5, 6, 7]
# [8, 9, 0]

# %%
from platform import python_version
print(python_version())
# Out:
# 3.7.3
