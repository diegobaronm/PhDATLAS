# %%
import ROOT
from ROOT import gStyle
import numpy as np
# Out:
# Welcome to JupyROOT 6.18/04

# %%
MC=ROOT.TFile.Open("MC.root","READ")
#Data = ROOT.TFile.Open("Data.root","READ")
Signal=ROOT.TFile.Open("Signal.root","READ")
VV=ROOT.TFile.Open("VV.root","READ")
Wjets=ROOT.TFile.Open("Wjets.root","READ")
Zjets=ROOT.TFile.Open("Zjet.root","READ")
Ttbar=ROOT.TFile.Open("ttbar.root","READ")
SingleTop=ROOT.TFile.Open("singletop.root","READ")

gStyle.SetOptStat(1111111)
a="reco_mass"

mc=MC.Get(a)
#data=Data.Get(a)
signal=Signal.Get(a)
vv=VV.Get(a)
w=Wjets.Get(a)
z=Zjets.Get(a)
tt=Ttbar.Get(a)
t=SingleTop.Get(a)

mc.SetDirectory(0)
signal.SetDirectory(0)
#data.SetDirectory(0)
vv.SetDirectory(0)
w.SetDirectory(0)
z.SetDirectory(0)
tt.SetDirectory(0)
t.SetDirectory(0)

MC.Close()
Signal.Close()
#Data.Close()
VV.Close()
Wjets.Close()
Zjets.Close()
Ttbar.Close()
SingleTop.Close()

hs = ROOT.THStack("hs","")
#'''
ob=300
s=0
e=300
n=6
nb=int(ob/n)
rebining=np.arange(s,e+n*(e-s)/ob,n*(e-s)/ob)
mc=mc.Rebin(nb,"signal",rebining)
signal=signal.Rebin(nb,"signal",rebining)
#data=data.Rebin(nb,"data",rebining)
vv=vv.Rebin(nb,"vv",rebining)
tt=tt.Rebin(nb,"tt",rebining)
t=t.Rebin(nb,"t",rebining)
z=z.Rebin(nb,"z",rebining)
w=w.Rebin(nb,"w",rebining)
#'''

w.SetFillColor(ROOT.kGreen)
w.SetLineColor(ROOT.kGreen)
z.SetFillColor(ROOT.kRed)
z.SetLineColor(ROOT.kRed)
vv.SetFillColor(ROOT.kBlue)
vv.SetLineColor(ROOT.kBlue)
tt.SetFillColor(ROOT.kYellow)
tt.SetLineColor(ROOT.kYellow)
t.SetFillColor(ROOT.kCyan)
t.SetLineColor(ROOT.kCyan)
#ata.SetLineColor(ROOT.kBlack)



hs.Add(vv)
hs.Add(w)
hs.Add(z)
hs.Add(tt)
hs.Add(t)
hs.Add(signal)

#ratio=mc.Clone()
#ratio.Divide(data)

gStyle.SetOptStat(1111111)

canvas3 = ROOT.TCanvas("canvas3")
canvas3.cd()

pad1 = ROOT . TPad (" pad1 "," pad1 " ,0 ,0.35 ,1 ,1)

pad1.Draw ()
pad1.cd ()




#data.Draw("pe")
hs.Draw("HIST same")

#pad1.SetLogy()


#data . GetYaxis (). SetRangeUser (0 ,1.2*data.GetBinContent(data.GetMaximumBin()))
#data . GetXaxis (). SetRangeUser (0 ,300e3)


#hs . GetXaxis (). SetRangeUser (20e3 ,30e4)
#hs . GetYaxis (). SetRangeUser (0 ,40)
legend = ROOT . TLegend (0.8 ,0.4 ,0.9 ,0.6)
legend . AddEntry ( vv ,"Diboson")
#legend . AddEntry ( data ," Data ")
legend . AddEntry ( signal ," Signal ")
legend . AddEntry ( w ," W+jets ")
legend . AddEntry ( z ," Z+jets ")
legend . AddEntry ( t ," Single top ")
legend . AddEntry ( tt ," ttbar ")

legend . SetLineWidth (0)
legend . Draw ()



hs.SetTitle(a)

canvas3.cd()
pad2 = ROOT . TPad (" pad2 "," pad2 " ,0 ,0.05 ,1 ,0.25)
pad2.Draw ()
'''pad2.cd ()
ratio.Draw ("pe")
ratio.SetStats(0)
ratio . GetYaxis (). SetRangeUser (-0.5 ,2.5)
ratio . GetXaxis (). SetRangeUser (0 ,300e3)
ratio . GetYaxis (). SetTitle ("MC/DATA")
ratio . GetYaxis (). SetTitleSize (0.15)
ratio . GetYaxis (). SetTitleOffset (0.25)
line = ROOT . TLine (0 ,1 ,300e3 ,1)
line . SetLineColor ( ROOT . kBlack )
line . SetLineWidth (2)
line . Draw (" same ")


'''





canvas3.Print(a+".pdf")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-426e0e42a9b6> in <module>
#     144
#     145
# --> 146 canvas3.Print(a+".pdf")
#     147
#
# TypeError: none of the 2 overloaded methods succeeded. Full details:
#   void TPad::Print(const char* filename = "") =>
#     problem in C++; program state has been reset
#   void TPad::Print(const char* filename, const char* option) =>
#     takes at least 2 arguments (1 given)
#  *** Break *** segmentation violation
#
#
#
# ===========================================================
# There was a crash.
# This is the entire stack trace of all threads:
# ===========================================================
#
# Thread 10 (Thread 0x7ff6e9ff0700 (LWP 4835)):
# #0  futex_abstimed_wait_cancelable (private=<optimised out>, abstime=0x7ff6e9fef440, clockid=<optimised out>, expected=0, futex_word=0x55cd4220aa64 <_PyRuntime+1252>) at ../sysdeps/unix/sysv/linux/futex-internal.h:208
# #1  __pthread_cond_wait_common (abstime=0x7ff6e9fef440, clockid=<optimised out>, mutex=0x55cd4220aa68 <_PyRuntime+1256>, cond=0x55cd4220aa38 <_PyRuntime+1208>) at pthread_cond_wait.c:520
# #2  __pthread_cond_timedwait (cond=0x55cd4220aa38 <_PyRuntime+1208>, mutex=0x55cd4220aa68 <_PyRuntime+1256>, abstime=0x7ff6e9fef440) at pthread_cond_wait.c:656
# #3  0x000055cd4204f405 in PyCOND_TIMEDWAIT (cond=0x55cd4220aa38 <_PyRuntime+1208>, mut=0x55cd4220aa68 <_PyRuntime+1256>, us=5000) at /tmp/build/80754af9/python_1553721932202/work/Python/condvar.h:90
# #4  take_gil (tstate=0x55cd43846920) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval_gil.h:208
# #5  PyEval_RestoreThread (tstate=0x55cd43846920) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:271
# #6  0x000055cd4206b050 in pysleep (secs=10000000) at /tmp/build/80754af9/python_1553721932202/work/Modules/timemodule.c:1830
# #7  time_sleep (self=<optimised out>, obj=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Modules/timemodule.c:371
# #8  0x000055cd4203450c in _PyMethodDef_RawFastCallKeywords (method=0x55cd421e10a0 <time_methods+288>, self=0x7ff705d1a228, args=0x7ff6d40013c0, nargs=<optimised out>, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:644
# #9  0x000055cd42034801 in _PyCFunction_FastCallKeywords (func=0x7ff705d17750, args=<optimised out>, nargs=<optimised out>, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:730
# #10 0x000055cd420902bc in call_function (kwnames=0x0, oparg=1, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4568
# #11 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3093
# #12 0x000055cd41fd14f9 in _PyEval_EvalCodeWithName (_co=0x7ff6ea2d3f60, globals=<optimised out>, locals=<optimised out>, args=<optimised out>, argcount=<optimised out>, kwnames=0x0, kwargs=0x7ff7000afbd8, kwcount=0, kwstep=1, defs=0x7ff6ea2d4990, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff6ea2d0b70, qualname=0x7ff6ea2ccb20) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3930
# #13 0x000055cd420339c5 in _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff7000afbc8, nargs=2, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:433
# #14 0x000055cd4208fed9 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #15 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3093
# #16 0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=2, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #17 _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff6ebf9dbe8, nargs=2, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #18 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #19 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #20 0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #21 _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff6d4000d08, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #22 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #23 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #24 0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #25 _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff6e9ff7380, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #26 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #27 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #28 0x000055cd41fd250b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=0x7ff705caf540) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #29 _PyFunction_FastCallDict (func=<optimised out>, args=0x7ff6e9fefe00, nargs=1, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:322
# #30 0x000055cd41fe9c43 in _PyObject_Call_Prepend (callable=0x7ff705c54d90, obj=<optimised out>, args=0x7ff705f57048, kwargs=0x0) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:904
# #31 0x000055cd41fde95e in PyObject_Call (callable=0x7ff7000861c8, args=<optimised out>, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:245
# #32 0x000055cd420de037 in t_bootstrap (boot_raw=0x7ff6ea2d5be8) at /tmp/build/80754af9/python_1553721932202/work/Modules/_threadmodule.c:994
# #33 0x000055cd4209e468 in pythread_wrapper (arg=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/thread_pthread.h:174
# #34 0x00007ff70686b669 in start_thread (arg=<optimised out>) at pthread_create.c:479
# #35 0x00007ff706793323 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
#
# Thread 9 (Thread 0x7ff6ebf7f700 (LWP 4802)):
# #0  0x00007ff70678929b in __GI___select (nfds=0, readfds=0x0, writefds=0x0, exceptfds=0x0, timeout=0x7ff6ebf7e890) at ../sysdeps/unix/sysv/linux/select.c:41
# #1  0x000055cd4206b044 in pysleep (secs=1000000000) at /tmp/build/80754af9/python_1553721932202/work/Modules/timemodule.c:1829
# #2  time_sleep (self=<optimised out>, obj=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Modules/timemodule.c:371
# #3  0x000055cd4203450c in _PyMethodDef_RawFastCallKeywords (method=0x55cd421e10a0 <time_methods+288>, self=0x7ff705d1a228, args=0x7ff70008c5b8, nargs=<optimised out>, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:644
# #4  0x000055cd42034801 in _PyCFunction_FastCallKeywords (func=0x7ff705d17750, args=<optimised out>, nargs=<optimised out>, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:730
# #5  0x000055cd420902bc in call_function (kwnames=0x0, oparg=1, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4568
# #6  _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3093
# #7  0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #8  _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff6e4000d08, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #9  0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #10 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #11 0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #12 _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff7000418c0, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #13 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #14 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #15 0x000055cd41fd250b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=0x7ff705caf540) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #16 _PyFunction_FastCallDict (func=<optimised out>, args=0x7ff6ebf7ee00, nargs=1, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:322
# #17 0x000055cd41fe9c43 in _PyObject_Call_Prepend (callable=0x7ff705c54d90, obj=<optimised out>, args=0x7ff705f57048, kwargs=0x0) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:904
# #18 0x000055cd41fde95e in PyObject_Call (callable=0x7ff7008df5c8, args=<optimised out>, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:245
# #19 0x000055cd420de037 in t_bootstrap (boot_raw=0x7ff70007e080) at /tmp/build/80754af9/python_1553721932202/work/Modules/_threadmodule.c:994
# #20 0x000055cd4209e468 in pythread_wrapper (arg=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/thread_pthread.h:174
# #21 0x00007ff70686b669 in start_thread (arg=<optimised out>) at pthread_create.c:479
# #22 0x00007ff706793323 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
#
# Thread 8 (Thread 0x7ff7008b1700 (LWP 4801)):
# #0  futex_abstimed_wait_cancelable (private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7ff6f003b5f0) at ../sysdeps/unix/sysv/linux/futex-internal.h:208
# #1  do_futex_wait (sem=sem
# entry=0x7ff6f003b5f0, abstime=0x0, clockid=0) at sem_waitcommon.c:112
# #2  0x00007ff706875488 in __new_sem_wait_slow (sem=0x7ff6f003b5f0, abstime=0x0, clockid=0) at sem_waitcommon.c:184
# #3  0x000055cd4202de69 in PyThread_acquire_lock_timed (lock=0x7ff6f003b5f0, microseconds=-1000000, intr_flag=1) at /tmp/build/80754af9/python_1553721932202/work/Python/thread_pthread.h:372
# #4  0x000055cd4206584a in acquire_timed (timeout=-1000000000, lock=0x7ff6f003b5f0) at /tmp/build/80754af9/python_1553721932202/work/Modules/_threadmodule.c:61
# #5  lock_PyThread_acquire_lock (self=0x7ff70007e030, args=<optimised out>, kwds=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Modules/_threadmodule.c:144
# #6  0x000055cd420346e4 in _PyMethodDef_RawFastCallKeywords (method=0x55cd421e0740 <lock_methods+32>, self=0x7ff70007e030, args=0x55cd44fb38c8, nargs=<optimised out>, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:690
# #7  0x000055cd4203486f in _PyMethodDescr_FastCallKeywords (descrobj=0x7ff705f54360, args=0x55cd44fb38c0, nargs=1, kwnames=0x0) at /tmp/build/80754af9/python_1553721932202/work/Objects/descrobject.c:288
# #8  0x000055cd4209007c in call_function (kwnames=0x0, oparg=1, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4593
# #9  _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #10 0x000055cd41fd14f9 in _PyEval_EvalCodeWithName (_co=0x7ff705d2eae0, globals=<optimised out>, locals=<optimised out>, args=<optimised out>, argcount=<optimised out>, kwnames=0x0, kwargs=0x7ff6e9ff65b8, kwcount=0, kwstep=1, defs=0x7ff705d2f610, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff705f02f80, qualname=0x7ff705ca24f0) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3930
# #11 0x000055cd420339c5 in _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff6e9ff65a8, nargs=2, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:433
# #12 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #13 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #14 0x000055cd41fd14f9 in _PyEval_EvalCodeWithName (_co=0x7ff705ca9780, globals=<optimised out>, locals=<optimised out>, args=<optimised out>, argcount=<optimised out>, kwnames=0x0, kwargs=0x7ff703937f28, kwcount=0, kwstep=1, defs=0x7ff705ca3e60, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff705f02f80, qualname=0x7ff705ca2930) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3930
# #15 0x000055cd420339c5 in _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff703937f20, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:433
# #16 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #17 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #18 0x000055cd41fd250b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=0x7ff704ebc660) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #19 _PyFunction_FastCallDict (func=<optimised out>, args=0x7ff703979f78, nargs=1, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:322
# #20 0x000055cd4208d250 in do_call_core (kwdict=0x7ff703961cf0, callargs=0x7ff703979f60, func=0x7ff704d22510) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4645
# #21 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3191
# #22 0x000055cd41fd14f9 in _PyEval_EvalCodeWithName (_co=0x7ff704ea1780, globals=<optimised out>, locals=<optimised out>, args=<optimised out>, argcount=<optimised out>, kwnames=0x0, kwargs=0x7ff7008b56c8, kwcount=0, kwstep=1, defs=0x0, defcount=0, kwdefs=0x0, closure=0x0, name=0x7ff704eae3f0, qualname=0x7ff704eae3f0) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3930
# #23 0x000055cd42033a27 in _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff7008b56b8, nargs=2, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:433
# #24 0x000055cd4208b846 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #25 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3124
# #26 0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #27 _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff6f0000d08, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #28 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #29 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #30 0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #31 _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff7008c01c0, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #32 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #33 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #34 0x000055cd41fd250b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=0x7ff705caf540) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #35 _PyFunction_FastCallDict (func=<optimised out>, args=0x7ff7008b0e00, nargs=1, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:322
# #36 0x000055cd41fe9c43 in _PyObject_Call_Prepend (callable=0x7ff705c54d90, obj=<optimised out>, args=0x7ff705f57048, kwargs=0x0) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:904
# #37 0x000055cd41fde95e in PyObject_Call (callable=0x7ff703963788, args=<optimised out>, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:245
# #38 0x000055cd420de037 in t_bootstrap (boot_raw=0x7ff7039267b0) at /tmp/build/80754af9/python_1553721932202/work/Modules/_threadmodule.c:994
# #39 0x000055cd4209e468 in pythread_wrapper (arg=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/thread_pthread.h:174
# #40 0x00007ff70686b669 in start_thread (arg=<optimised out>) at pthread_create.c:479
# #41 0x00007ff706793323 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
#
# Thread 7 (Thread 0x7ff7010f2700 (LWP 4800)):
# #0  0x00007ff70679365e in epoll_wait (epfd=29, events=0x7ff7010f11f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
# #1  0x00007ff70410b4ed in zmq::epoll_t::loop() () from /home/diegol/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
# #2  0x00007ff704141f86 in thread_routine () from /home/diegol/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
# #3  0x00007ff70686b669 in start_thread (arg=<optimised out>) at pthread_create.c:479
# #4  0x00007ff706793323 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
#
# Thread 6 (Thread 0x7ff7018f3700 (LWP 4799)):
# #0  0x00007ff70679365e in epoll_wait (epfd=27, events=0x7ff7018f21f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
# #1  0x00007ff70410b4ed in zmq::epoll_t::loop() () from /home/diegol/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
# #2  0x00007ff704141f86 in thread_routine () from /home/diegol/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
# #3  0x00007ff70686b669 in start_thread (arg=<optimised out>) at pthread_create.c:479
# #4  0x00007ff706793323 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
#
# Thread 5 (Thread 0x7ff7020f4700 (LWP 4798)):
# #0  0x00007ff706786c2f in __GI___poll (fds=0x7ff7020f3590, nfds=2, timeout=-1) at ../sysdeps/unix/sysv/linux/poll.c:29
# #1  0x00007ff7041502bc in zmq_poll () from /home/diegol/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
# #2  0x00007ff7041229c2 in zmq::proxy(zmq::socket_base_t*, zmq::socket_base_t*, zmq::socket_base_t*, zmq::socket_base_t*) () from /home/diegol/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
# #3  0x00007ff703c3caae in __pyx_pw_3zmq_7backend_6cython_7_device_3proxy () from /home/diegol/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/_device.cpython-37m-x86_64-linux-gnu.so
# #4  0x00007ff703c3e6ff in __pyx_pw_3zmq_7backend_6cython_7_device_1device () from /home/diegol/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/_device.cpython-37m-x86_64-linux-gnu.so
# #5  0x000055cd42034d2b in _PyObject_FastCallKeywords (callable=0x7ff703cb73e0, stack=0x7ff703907998, nargs=3, kwnames=0x0) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:199
# #6  0x000055cd420907ae in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4619
# #7  _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3093
# #8  0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #9  _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff6f8000d08, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #10 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #11 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #12 0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #13 _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff703924700, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #14 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #15 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #16 0x000055cd41fd250b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=0x7ff705caf540) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #17 _PyFunction_FastCallDict (func=<optimised out>, args=0x7ff7020f3e00, nargs=1, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:322
# #18 0x000055cd41fe9c43 in _PyObject_Call_Prepend (callable=0x7ff705c54d90, obj=<optimised out>, args=0x7ff705f57048, kwargs=0x0) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:904
# #19 0x000055cd41fde95e in PyObject_Call (callable=0x7ff705f49a08, args=<optimised out>, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:245
# #20 0x000055cd420de037 in t_bootstrap (boot_raw=0x7ff7039a17d8) at /tmp/build/80754af9/python_1553721932202/work/Modules/_threadmodule.c:994
# #21 0x000055cd4209e468 in pythread_wrapper (arg=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/thread_pthread.h:174
# #22 0x00007ff70686b669 in start_thread (arg=<optimised out>) at pthread_create.c:479
# #23 0x00007ff706793323 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
#
# Thread 4 (Thread 0x7ff7028f5700 (LWP 4797)):
# #0  0x00007ff70679365e in epoll_wait (epfd=19, events=0x7ff7008cc738, maxevents=3, timeout=-1000) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
# #1  0x00007ff705ce3f57 in pyepoll_poll (self=0x7ff70481ccf0, args=<optimised out>, kwds=<optimised out>) at /usr/local/src/conda/python-3.7.3/Modules/selectmodule.c:1562
# #2  0x000055cd420346e4 in _PyMethodDef_RawFastCallKeywords (method=0x7ff705ce9f40 <pyepoll_methods+192>, self=0x7ff70481ccf0, args=0x55cd433a2888, nargs=<optimised out>, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:690
# #3  0x000055cd4203486f in _PyMethodDescr_FastCallKeywords (descrobj=0x7ff705d22ca8, args=0x55cd433a2880, nargs=3, kwnames=0x0) at /tmp/build/80754af9/python_1553721932202/work/Objects/descrobject.c:288
# #4  0x000055cd4209007c in call_function (kwnames=0x0, oparg=3, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4593
# #5  _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #6  0x000055cd41fd14f9 in _PyEval_EvalCodeWithName (_co=0x7ff705d2e4b0, globals=<optimised out>, locals=<optimised out>, args=<optimised out>, argcount=<optimised out>, kwnames=0x0, kwargs=0x7ff6f40013d8, kwcount=0, kwstep=1, defs=0x7ff705d2f178, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff705d14928, qualname=0x7ff705d2acd8) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3930
# #7  0x000055cd420339c5 in _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff6f40013c8, nargs=2, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:433
# #8  0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #9  _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #10 0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #11 _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff7039251c8, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #12 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #13 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #14 0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #15 _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff70390eee8, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #16 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #17 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #18 0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #19 _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff703909bb0, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #20 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #21 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #22 0x000055cd41fd250b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=0x7ff703a62b70) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #23 _PyFunction_FastCallDict (func=<optimised out>, args=0x7ff7028f48b0, nargs=1, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:322
# #24 0x000055cd41fe9c43 in _PyObject_Call_Prepend (callable=0x7ff7039ec0d0, obj=<optimised out>, args=0x7ff705f57048, kwargs=0x7ff7039196c0) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:904
# #25 0x000055cd41fde95e in PyObject_Call (callable=0x7ff70390a4c8, args=<optimised out>, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:245
# #26 0x000055cd4208d250 in do_call_core (kwdict=0x7ff7039196c0, callargs=0x7ff705f57048, func=0x7ff70390a4c8) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4645
# #27 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3191
# #28 0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #29 _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff6f4000d08, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #30 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #31 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #32 0x000055cd4203379b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #33 _PyFunction_FastCallKeywords (func=<optimised out>, stack=0x7ff703977fc0, nargs=1, kwnames=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:408
# #34 0x000055cd4208bad0 in call_function (kwnames=0x0, oparg=<optimised out>, pp_stack=<synthetic pointer>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:4616
# #35 _PyEval_EvalFrameDefault (f=<optimised out>, throwflag=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/ceval.c:3110
# #36 0x000055cd41fd250b in function_code_fastcall (globals=<optimised out>, nargs=1, args=<optimised out>, co=0x7ff705caf540) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:283
# #37 _PyFunction_FastCallDict (func=<optimised out>, args=0x7ff7028f4e00, nargs=1, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:322
# #38 0x000055cd41fe9c43 in _PyObject_Call_Prepend (callable=0x7ff705c54d90, obj=<optimised out>, args=0x7ff705f57048, kwargs=0x0) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:904
# #39 0x000055cd41fde95e in PyObject_Call (callable=0x7ff70390a488, args=<optimised out>, kwargs=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Objects/call.c:245
# #40 0x000055cd420de037 in t_bootstrap (boot_raw=0x7ff7039a1b70) at /tmp/build/80754af9/python_1553721932202/work/Modules/_threadmodule.c:994
# #41 0x000055cd4209e468 in pythread_wrapper (arg=<optimised out>) at /tmp/build/80754af9/python_1553721932202/work/Python/thread_pthread.h:174
# #42 0x00007ff70686b669 in start_thread (arg=<optimised out>) at pthread_create.c:479
# #43 0x00007ff706793323 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
#
# Thread 3 (Thread 0x7ff7030f6700 (LWP 4796)):
# #0  0x00007ff70679365e in epoll_wait (epfd=10, events=0x7ff7030f51f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
# #1  0x00007ff70410b4ed in zmq::epoll_t::loop() () from /home/diegol/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
# #2  0x00007ff704141f86 in thread_routine () from /home/diegol/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
# #3  0x00007ff70686b669 in start_thread (arg=<optimised out>) at pthread_create.c:479
# #4  0x00007ff706793323 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
#
# Thread 2 (Thread 0x7ff7038f7700 (LWP 4795)):
# #0  0x00007ff70679365e in epoll_wait (epfd=8, events=0x7ff7038f61f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
# #1  0x00007ff70410b4ed in zmq::epoll_t::loop() () from /home/diegol/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
# #2  0x00007ff704141f86 in thread_routine () from /home/diegol/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
# #3  0x00007ff70686b669 in start_thread (arg=<optimised out>) at pthread_create.c:479
# #4  0x00007ff706793323 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
#
# Thread 1 (Thread 0x7ff706507740 (LWP 4791)):
# #0  0x00007ff706756a86 in __GI___waitpid (pid=4860, stat_loc=stat_loc
# entry=0x7ffc4a433048, options=options
# entry=0) at ../sysdeps/unix/sysv/linux/waitpid.c:30
# #1  0x00007ff7066c624f in do_system (line=<optimised out>) at ../sysdeps/posix/system.c:167
# #2  0x00007ff6eab17cf0 in TUnixSystem::Exec (shellcmd=<optimised out>, this=0x55cd433a9130) at /home/diegol/Downloads/root-6.18.04/core/unix/src/TUnixSystem.cxx:2106
# #3  TUnixSystem::StackTrace (this=0x55cd433a9130) at /home/diegol/Downloads/root-6.18.04/core/unix/src/TUnixSystem.cxx:2400
# #4  0x00007ff6eab1a754 in TUnixSystem::DispatchSignals (this=0x55cd433a9130, sig=kSigSegmentationViolation) at /home/diegol/Downloads/root-6.18.04/core/unix/src/TUnixSystem.cxx:3631
# #5  <signal handler called>
# #6  std::__atomic_base<bool>::load (__m=std::memory_order_seq_cst, this=0x1b0) at /usr/include/c++/8/bits/atomic_base.h:390
# #7  std::atomic<bool>::operator bool (this=0x1b0) at /usr/include/c++/8/atomic:86
# #8  TClass::HasDataMemberInfo (this=0x0) at /home/diegol/Downloads/ROOT6/include/TClass.h:378
# #9  TClass::DynamicCast (this=this
# entry=0x0, cl=0x55cd43ae74d0, obj=obj
# entry=0x55cd46a296b0, up=up
# entry=true) at /home/diegol/Downloads/root-6.18.04/core/meta/src/TClass.cxx:4787
# #10 0x00007ff6d888d284 in THStack::Paint (this=0x55cd46519060, choptin=<optimised out>) at /home/diegol/Downloads/ROOT6/include/TClassRef.h:74
# #11 0x00007ff6d841b6f3 in TPad::Paint (this=0x55cd44938760) at /home/diegol/Downloads/ROOT6/include/TString.h:239
# #12 0x00007ff6d841b6f3 in TPad::Paint (this=0x55cd454488c0) at /home/diegol/Downloads/ROOT6/include/TString.h:239
# #13 0x00007ff6d8411b13 in TPad::Print (this=0x55cd454488c0, filenam=<optimised out>, option=<optimised out>) at /home/diegol/Downloads/root-6.18.04/graf2d/gpad/src/TPad.cxx:5098
# #14 0x00007ff6d840943f in TPad::SaveAs (this=0x55cd454488c0, filename=<optimised out>) at /home/diegol/Downloads/ROOT6/include/TString.h:239
# #15 0x00007ff6e8050065 in ?? ()
# #16 0x0000000000000000 in ?? ()
# ===========================================================
#
#
# The lines below might hint at the cause of the crash.
# You may get help by asking at the ROOT forum http://root.cern.ch/forum
# Only if you are really convinced it is a bug in ROOT then please submit a
# report at http://root.cern.ch/bugs Please post the ENTIRE stack trace
# from above as an attachment in addition to anything else
# that might help us fixing this issue.
# ===========================================================
# #6  std::__atomic_base<bool>::load (__m=std::memory_order_seq_cst, this=0x1b0) at /usr/include/c++/8/bits/atomic_base.h:390
# #7  std::atomic<bool>::operator bool (this=0x1b0) at /usr/include/c++/8/atomic:86
# #8  TClass::HasDataMemberInfo (this=0x0) at /home/diegol/Downloads/ROOT6/include/TClass.h:378
# #9  TClass::DynamicCast (this=this
# entry=0x0, cl=0x55cd43ae74d0, obj=obj
# entry=0x55cd46a296b0, up=up
# entry=true) at /home/diegol/Downloads/root-6.18.04/core/meta/src/TClass.cxx:4787
# #10 0x00007ff6d888d284 in THStack::Paint (this=0x55cd46519060, choptin=<optimised out>) at /home/diegol/Downloads/ROOT6/include/TClassRef.h:74
# #11 0x00007ff6d841b6f3 in TPad::Paint (this=0x55cd44938760) at /home/diegol/Downloads/ROOT6/include/TString.h:239
# #12 0x00007ff6d841b6f3 in TPad::Paint (this=0x55cd454488c0) at /home/diegol/Downloads/ROOT6/include/TString.h:239
# #13 0x00007ff6d8411b13 in TPad::Print (this=0x55cd454488c0, filenam=<optimised out>, option=<optimised out>) at /home/diegol/Downloads/root-6.18.04/graf2d/gpad/src/TPad.cxx:5098
# #14 0x00007ff6d840943f in TPad::SaveAs (this=0x55cd454488c0, filename=<optimised out>) at /home/diegol/Downloads/ROOT6/include/TString.h:239
# #15 0x00007ff6e8050065 in ?? ()
# #16 0x0000000000000000 in ?? ()
# ===========================================================

# %%
data.Integral(90,502)
# Out:
# 0.0

# %% [markdown]
# ### PLOT SINGULAR PROPERTIES

# %%
File="Wjets.root"
histo="tau_matched"

Signal=ROOT.TFile.Open(File,"READ")
signal=Signal.Get(histo)
canvas4=ROOT.TCanvas("canvas4")
canvas4.cd()
#signal=signal.Rebin(50,"signal",rebining)
signal.Draw("HIST")
signal.SetFillColor(ROOT.kGreen)
signal.SetLineColor(ROOT.kGreen)
signal.SetTitle(histo)

legend = ROOT.TLegend (0.5 ,0.5 ,0.85 ,0.55)
legend.AddEntry ( signal ,File[:-5])
legend.Draw("same")

canvas4.Print(File[:-5]+"_"+histo+".pdf")

# %% [markdown]
# ### PLOTTING BDT SCORE

# %%
canvas5=ROOT.TCanvas("canvas5")
canvas5.cd()
w.Draw("HIST")
z.Draw("HIST,same")
vv.Draw("HIST,same")
tt.Draw("HIST,same")
t.Draw("HIST,same")
signal.Draw("HIST,same")


w.SetLineColor(ROOT.kGreen)

z.SetLineColor(ROOT.kRed)

vv.SetLineColor(ROOT.kBlue)

tt.SetLineColor(ROOT.kYellow)

t.SetLineColor(ROOT.kCyan)

legend.Draw()

canvas5.SetLogy()

canvas5.Print("BDT_score.pdf")

# %%
rebining

# %%
MC=ROOT.TFile.Open("MC.root","READ")
Signal=ROOT.TFile.Open("Signal.root","READ")
VV=ROOT.TFile.Open("VV.root","READ")
Wjets=ROOT.TFile.Open("Wjets.root","READ")
Zjets=ROOT.TFile.Open("Zjet.root","READ")
Ttbar=ROOT.TFile.Open("ttbar.root","READ")
SingleTop=ROOT.TFile.Open("singletop.root","READ")

gStyle.SetOptStat(1111111)
a="reco_mass_jetn_btag_iso_bdt_tmass_omega"

mc=MC.Get(a)
signal=Signal.Get(a)
vv=VV.Get(a)
w=Wjets.Get(a)
z=Zjets.Get(a)
tt=Ttbar.Get(a)
t=SingleTop.Get(a)

mc.SetDirectory(0)
signal.SetDirectory(0)
vv.SetDirectory(0)
w.SetDirectory(0)
z.SetDirectory(0)
tt.SetDirectory(0)
t.SetDirectory(0)

MC.Close()
Signal.Close()
VV.Close()
Wjets.Close()
Zjets.Close()
Ttbar.Close()
SingleTop.Close()

hs = ROOT.THStack("hs","")
#'''
ob=300
s=0
e=300
n=6
nb=int(ob/n)
rebining=np.arange(s,e+n*(e-s)/ob,n*(e-s)/ob)
mc=mc.Rebin(nb,"signal",rebining)
signal=signal.Rebin(nb,"signal",rebining)
#data=data.Rebin(nb,"data",rebining)
vv=vv.Rebin(nb,"vv",rebining)
tt=tt.Rebin(nb,"tt",rebining)
t=t.Rebin(nb,"t",rebining)
z=z.Rebin(nb,"z",rebining)
w=w.Rebin(nb,"w",rebining)
#'''

w.SetFillColor(ROOT.kGreen)
w.SetLineColor(ROOT.kGreen)
z.SetFillColor(ROOT.kRed)
z.SetLineColor(ROOT.kRed)
vv.SetFillColor(ROOT.kBlue)
vv.SetLineColor(ROOT.kBlue)
tt.SetFillColor(ROOT.kYellow)
tt.SetLineColor(ROOT.kYellow)
t.SetFillColor(ROOT.kCyan)
t.SetLineColor(ROOT.kCyan)




hs.Add(vv)
hs.Add(w)
hs.Add(z)
hs.Add(tt)
hs.Add(t)
hs.Add(signal)




canvas6 = ROOT.TCanvas("canvas8")
canvas6.cd()


hs.Draw("HIST")

legend = ROOT . TLegend (0.8 ,0.4 ,0.9 ,0.6)
legend . AddEntry ( vv ,"Diboson")
legend . AddEntry ( signal ," Signal ")
legend . AddEntry ( w ," W+jets ")
legend . AddEntry ( z ," Z+jets ")
legend . AddEntry ( t ," Single top ")
legend . AddEntry ( tt ," ttbar ")

legend . SetLineWidth (0)
legend . Draw ()



hs.SetTitle(a)





canvas6.Print(a+".pdf")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas8
# Info in <TCanvas::Print>: pdf file reco_mass_jetn_btag_iso_bdt_tmass_omega.pdf has been created
